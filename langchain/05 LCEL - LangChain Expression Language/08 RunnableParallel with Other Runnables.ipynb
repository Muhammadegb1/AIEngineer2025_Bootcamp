# %% [markdown]
# # Piping a RunnableParallel with Other Runnables

# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableParallel

# %%
chat_template_books = ChatPromptTemplate.from_template(
    '''
    Suggest three of the best intermediate-level {programming language} books. 
    Answer only by listing the books.
    '''
)

chat_template_projects = ChatPromptTemplate.from_template(
    '''
    Suggest three interesting {programming language} projects suitable for intermediate-level programmers. 
    Answer only by listing the projects.
    '''
)

chat_template_time = ChatPromptTemplate.from_template(
     '''
     I'm an intermediate level programmer.
     
     Consider the following literature:
     {books}
     
     Also, consider the following projects:
     {projects}
     
     Roughly how much time would it take me to complete the literature and the projects?
     
     '''
)

# %%
chat = ChatOpenAI(model_name = 'gpt-4', 
                  model_kwargs = {'seed':365},
                  temperature = 0,
                  max_tokens = 500)

# %%
string_parser = StrOutputParser()

# %%
chain_books = chat_template_books | chat | string_parser

chain_projects = chat_template_projects | chat | string_parser

# %%
chain_parallel = RunnableParallel({'books':chain_books, 'projects':chain_projects})

# %%
chain_parallel.invoke({'programming language':'Python'})
# Out:
# {'books': '1. "Fluent Python: Clear, Concise, and Effective Programming" by Luciano Ramalho\n2. "Python Cookbook: Recipes for Mastering Python 3" by David Beazley and Brian K. Jones\n3. "Effective Python: 90 Specific Ways to Write Better Python" by Brett Slatkin',
#  'projects': '1. Building a Weather Forecasting Application using APIs.\n2. Developing a Web Scraper for E-commerce Websites.\n3. Creating a Text-based Adventure Game with multiple scenarios.'}

# %%
chain_time1 = (RunnableParallel({'books':chain_books, 
                                'projects':chain_projects}) 
              | chat_template_time 
              | chat 
              | string_parser
             )

# %%
print(chain_time1.invoke({'programming language':'Python'}))
# Out:
# The time it takes to complete the literature and the projects can vary greatly depending on several factors such as your current skill level, the amount of time you can dedicate each day, your reading speed, and how quickly you grasp new concepts.
#
# For the literature:
#
# 1. "Fluent Python: Clear, Concise, and Effective Programming" by Luciano Ramalho - This book is around 800 pages. If you read and practice for about 2 hours a day, it might take you around 4-6 weeks to complete.
#
# 2. "Python Cookbook: Recipes for Mastering Python 3" by David Beazley and Brian K. Jones - This book is around 700 pages. Again, if you read and practice for about 2 hours a day, it might take you around 3-5 weeks to complete.
#
# 3. "Effective Python: 90 Specific Ways to Write Better Python" by Brett Slatkin - This book is around 230 pages. If you read and practice for about 2 hours a day, it might take you around 2-3 weeks to complete.
#
# For the projects:
#
# 1. Building a Weather Forecasting Application using APIs - Depending on the complexity of the application, this could take anywhere from a few days to a couple of weeks.
#
# 2. Developing a Text-to-Speech Conversion Program - This could take a few days to a week, depending on your familiarity with the libraries and tools you'll be using.
#
# 3. Creating a Personal Finance Tracker with Data Visualization - This could be a more complex project that might take a few weeks to a month, depending on the features you want to include.
#
# In total, if you're dedicating about 2-3 hours a day, you might expect to spend around 4-6 months to complete all the books and projects. This is a rough estimate and the actual time could be less or more depending on the factors mentioned earlier.

# %%
chain_time1.get_graph().print_ascii()
# Out:
#             +-------------------------------+
#             | Parallel<books,projects>Input |
#             +-------------------------------+
#                    ***               ***
#                 ***                     ***
#               **                           **
# +--------------------+              +--------------------+
# | ChatPromptTemplate |              | ChatPromptTemplate |
# +--------------------+              +--------------------+
#            *                                   *
#            *                                   *
#            *                                   *
#     +------------+                      +------------+
#     | ChatOpenAI |                      | ChatOpenAI |
#     +------------+                      +------------+
#            *                                   *
#            *                                   *
#            *                                   *
#   +-----------------+                 +-----------------+
#   | StrOutputParser |                 | StrOutputParser |
#   +-----------------+                 +-----------------+
#                    ***               ***
#                       ***         ***
#                          **     **
#             +--------------------------------+
#             | Parallel<books,projects>Output |
#             +--------------------------------+
#                              *
#                              *
#                              *
#                   +--------------------+
#                   | ChatPromptTemplate |
#                   +--------------------+
#                              *
#                              *
#                              *
#                       +------------+
#                       | ChatOpenAI |
#                       +------------+
#                              *
#                              *
#                              *
#                     +-----------------+
#                     | StrOutputParser |
#                     +-----------------+
#                              *
#                              *
#                              *
#                 +-----------------------+
#                 | StrOutputParserOutput |
#                 +-----------------------+

# %%
chain_time2 = ({'books':chain_books, 
                'projects':chain_projects}
              | chat_template_time 
              | chat 
              | string_parser
             )

# %%
print(chain_time2.invoke({'programming language':'Python'}))
# Out:
# The time it takes to complete the literature and the projects can vary greatly depending on several factors such as your reading speed, comprehension level, the complexity of the projects, and the amount of time you can dedicate each day.
#
# However, here's a rough estimate:
#
# 1. "Fluent Python: Clear, Concise, and Effective Programming" - This book has around 800 pages. If you read and practice for about 2 hours a day, it might take you around 2-3 months to complete.
#
# 2. "Python Cookbook: Recipes for Mastering Python 3" - This book has around 700 pages. Again, if you read and practice for about 2 hours a day, it might take you around 2-3 months to complete.
#
# 3. "Effective Python: 90 Specific Ways to Write Better Python" - This book is a bit shorter with around 250 pages. If you read and practice for about 2 hours a day, it might take you around 1 month to complete.
#
# As for the projects:
#
# 1. Building a Weather Forecasting Application using APIs - If you work on this for about 2-3 hours a day, it might take you around 1-2 weeks to complete, depending on the complexity of the application.
#
# 2. Developing a Personal Finance Tracker with Data Visualization - This could be a bit more complex and might take you around 2-3 weeks to complete if you work on it for about 2-3 hours a day.
#
# 3. Creating a Text-based Adventure Game with Multiple Scenarios - This could be the most complex project and might take you around 1 month to complete if you work on it for about 2-3 hours a day.
#
# So in total, if you're dedicating around 2-3 hours a day for reading and practicing, it might take you around 7-10 months to complete all the books and projects. Please note that these are rough estimates and the actual time could be less or more depending on various factors.

# %%
chain_time2.get_graph().print_ascii()
# Out:
#             +-------------------------------+
#             | Parallel<books,projects>Input |
#             +-------------------------------+
#                    ***               ***
#                 ***                     ***
#               **                           **
# +--------------------+              +--------------------+
# | ChatPromptTemplate |              | ChatPromptTemplate |
# +--------------------+              +--------------------+
#            *                                   *
#            *                                   *
#            *                                   *
#     +------------+                      +------------+
#     | ChatOpenAI |                      | ChatOpenAI |
#     +------------+                      +------------+
#            *                                   *
#            *                                   *
#            *                                   *
#   +-----------------+                 +-----------------+
#   | StrOutputParser |                 | StrOutputParser |
#   +-----------------+                 +-----------------+
#                    ***               ***
#                       ***         ***
#                          **     **
#             +--------------------------------+
#             | Parallel<books,projects>Output |
#             +--------------------------------+
#                              *
#                              *
#                              *
#                   +--------------------+
#                   | ChatPromptTemplate |
#                   +--------------------+
#                              *
#                              *
#                              *
#                       +------------+
#                       | ChatOpenAI |
#                       +------------+
#                              *
#                              *
#                              *
#                     +-----------------+
#                     | StrOutputParser |
#                     +-----------------+
#                              *
#                              *
#                              *
#                 +-----------------------+
#                 | StrOutputParserOutput |
#                 +-----------------------+
